# %%
import pandas as pd
import ast

gpt_df = pd.read_csv('/Users/jinminseong/Desktop/2시연용데이터_article_summary_insights_완료.csv')

# %%
def splited(row):
    sperate_dic1 = {}
    sperate_dic2 = {}
    
    for key, value in row.items():
        if key == '2 기업 추출':
            sperate_dic1[key] = value
        else:
            sperate_dic2[key] = value
            
    return sperate_dic1, sperate_dic2

def distrbuted(row):
    corporation = []
    score = []
    if row == {}:
        return corporation, score
    elem = row['2 기업 추출']
    
    for key, value in elem.items():
        corporation.append(key)
        score.append(value)
    return corporation, score

# %%
gpt_df['insights'] = gpt_df['insights'].apply(ast.literal_eval)
temp = gpt_df['insights'].apply(splited)

# %%
gpt_df['기업추출'], gpt_df['insights1'] = zip(*temp)

# %%
gpt_df['기업추출']
# Out:
# 0               {'2 기업 추출': {'카메코': '5', '옐로케이크': '3'}}
# 1     {'2 기업 추출': {'삼성': '3', '마이크로소프트': '2', '트럼프 대...
# 2          {'2 기업 추출': {'DGB금융그룹': '3', '김태오 회장': '4'}}
# 3                                                    {}
# 4     {'2 기업 추출': {'유진투자증권': '3', '한국에너지공단': '4', '싱...
# 5     {'2 기업 추출': {'바이든': '5', '트럼프': '2', '조 바이든': ...
# 6     {'2 기업 추출': {'닛케이': '4', '삼요코': '3', '일본 기업': ...
# 7                                                    {}
# 8                                                    {}
# 9     {'2 기업 추출': {'마이크로소프트': '4', '삼성전자': '3', 'SK하...
# 10    {'2 기업 추출': {'삼성': '4', '마이크로소프트': '2', '한나증권'...
# 11                                                   {}
# 12                                                   {}
# 13                                                   {}
# 14    {'2 기업 추출': {'뉴욕생명자산운용': '3', '한국경제신문': '4', '...
# 15                                                   {}
# 16    {'2 기업 추출': {'프레시안': '4', '더불어민주당': '4', '국민의힘...
# ...

# %%
temp_insight = pd.json_normalize(gpt_df['insights1'])
temp_insight2 = gpt_df['기업추출'].apply(distrbuted)
gpt_df['기업'], gpt_df['score'] = zip(*temp_insight2)

gpt_df = pd.concat([gpt_df, temp_insight], axis=1)

# %%
gpt_df.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료.csv', index=False)

# %%
gpt_df.head()
# Out:
#         PublicationDate                                      title  \
# 0   2024.01.07. 오후 4:09  주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 1  2024.01.20. 오전 12:13          [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 2   2024.01.10. 오후 5:55  ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 3   2024.01.10. 오후 5:55  ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 4   2024.01.04. 오후 5:31                                  오늘의 인사 종합
#
#   media_outlet                                               link  \
# 0         시사저널  https://n.news.naver.com/mnews/article/586/000...
# 1     중앙SUNDAY  https://n.news.naver.com/mnews/article/353/000...
# 2         매일신문  https://n.news.naver.com/mnews/article/088/000...
# 3         매일신문  https://n.news.naver.com/mnews/article/088/000...
# 4         이데일리  https://n.news.naver.com/mnews/article/018/000...
#
#                                                 Body  \
# 0  파운드당 40달러에서 90달러로 2년간 가격 급상승…ETF 활용한 간접투자뿐 아니라...
# 1  전광우 세계경제연구원 이사장·전 금융위원장           2023년이 주식 투자...
# ...

# %%
comment = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', '기업', 'score', '1 esg관련주식 유망요소, 위협요소추출', '3 주식 트랜드 분석', '4 esg 관련 주식 이해관계자 인물, 기관 기업 추출', '5 esg 관련 테마 추출'], axis=1)

corp = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', 'score', '1 esg관련주식 유망요소, 위협요소추출', '3 주식 트랜드 분석', '4 esg 관련 주식 이해관계자 인물, 기관 기업 추출', '5 esg 관련 테마 추출'], axis=1)

score = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', '기업', '1 esg관련주식 유망요소, 위협요소추출', '3 주식 트랜드 분석', '4 esg 관련 주식 이해관계자 인물, 기관 기업 추출', '5 esg 관련 테마 추출'], axis=1)

esg_threaten = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', 'score', '3 주식 트랜드 분석', '4 esg 관련 주식 이해관계자 인물, 기관 기업 추출', '5 esg 관련 테마 추출'], axis=1)

trend = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', 'score', '1 esg관련주식 유망요소, 위협요소추출', '4 esg 관련 주식 이해관계자 인물, 기관 기업 추출', '5 esg 관련 테마 추출'], axis=1)

stakeholder = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', 'score', '1 esg관련주식 유망요소, 위협요소추출', '3 주식 트랜드 분석', '5 esg 관련 테마 추출'], axis=1)

theme = gpt_df.drop(['insights', 'Body', '기업추출', 'insights1', 'score', '1 esg관련주식 유망요소, 위협요소추출', '3 주식 트랜드 분석', '4 esg 관련 주식 이해관계자 인물, 기관 기업 추출'], axis=1)

# %%
corp
# Out:
#          PublicationDate                                              title  \
# 0    2024.01.07. 오후 4:09          주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 1   2024.01.20. 오전 12:13                  [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 2    2024.01.10. 오후 5:55          ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 3    2024.01.10. 오후 5:55          ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 4    2024.01.04. 오후 5:31                                          오늘의 인사 종합
# 5    2024.01.05. 오전 6:00                          2024년 선거의 해, 친환경 관련주의 운명은
# 6    2024.01.04. 오전 1:42                      [김현기의 시시각각] '대한민국의 봄'은 언제 오려나
# 7   2024.01.19. 오후 12:53                   정부 '감세 정책' 줄줄이..증시 부양효과? 세수 부족은?
# 8    2024.01.17. 오후 5:54                            토스증권, 2024 주식시장 보물찾기 발행
# 9    2024.01.18. 오후 5:50                            金채굴기업 투자까지 … 입지 넓히는 ETF
# 10   2024.01.16. 오전 6:54  최고의 ‘투자 길잡이’...베스트 애널리스트는 누구? [2023 하반기 베스트 애널...
# ...

# %%
corp = corp.explode('기업')
score = score.explode('score')
assert len(corp) == len(score)
corp = pd.concat([corp, score['score']], axis=1)
corp
# Out:
#          PublicationDate                                      title  \
# 0    2024.01.07. 오후 4:09  주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 0    2024.01.07. 오후 4:09  주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 1   2024.01.20. 오전 12:13          [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 1   2024.01.20. 오전 12:13          [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 1   2024.01.20. 오전 12:13          [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# ..                   ...                                        ...
# 19   2024.01.20. 오후 3:01                                    여성들이 온다
# 20   2024.01.05. 오전 5:58                       기후위기 대응에도 오일머니 작용했나?
# 21   2024.01.06. 오전 1:54           “정부·기업만으로 기후위기 못 막아…소비자 참여 유도해야”
# 21   2024.01.06. 오전 1:54           “정부·기업만으로 기후위기 못 막아…소비자 참여 유도해야”
# 21   2024.01.06. 오전 1:54           “정부·기업만으로 기후위기 못 막아…소비자 참여 유도해야”
#
#    media_outlet                                               link  \
# 0          시사저널  https://n.news.naver.com/mnews/article/586/000...
# ...

# %%
from ast import literal_eval
def safe_literal_eval(s):
    try:
        # Only evaluate if string looks like a Python literal
        if s.startswith(('[', '{')) and s.endswith((']', '}')):
            return literal_eval(s)
        else:
            return []
    except ValueError:
        return []

comment['comments'] = comment['comments'].apply(safe_literal_eval)
esg_threaten = esg_threaten['1 esg관련주식 유망요소, 위협요소추출'].apply(safe_literal_eval)
stakeholder['4 esg 관련 주식 이해관계자 인물, 기관 기업 추출'] = stakeholder.apply(safe_literal_eval)
theme['5 esg 관련 테마 추출'] = theme.apply(safe_literal_eval)

comment = comment[comment['comments'].apply(lambda x: len(x) > 0)]
esg_threaten = esg_threaten[esg_threaten.apply(lambda x: len(x) > 0)]
trend = trend[trend['3 주식 트랜드 분석'].apply(lambda x: len(x) > 0)]
stakeholder = stakeholder[stakeholder['4 esg 관련 주식 이해관계자 인물, 기관 기업 추출'].apply(lambda x: len(x) > 0)]
theme = theme[theme['5 esg 관련 테마 추출'].apply(lambda x: len(x) > 0)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[244], line 12
#       9     except ValueError:
#      10         return []
# ---> 12 comment['comments'] = comment['comments'].apply(safe_literal_eval)
#      13 esg_threaten = esg_threaten['1 esg관련주식 유망요소, 위협요소추출'].apply(safe_literal_eval)
#      14 stakeholder['4 esg 관련 주식 이해관계자 인물, 기관 기업 추출'] = stakeholder.apply(safe_literal_eval)
#
# File ~/Desktop/public_opinion_analyzer/.venv/lib/python3.12/site-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
# ...

# %%
stakeholder = stakeholder.explode('4 esg 관련 주식 이해관계자 인물, 기관 기업 추출')

# %%
comment = comment.explode('comments')
esg_threaten = esg_threaten.explode('1 esg관련주식 유망요소, 위협요소추출')
trend = trend.explode('3 주식 트랜드 분석').dropna()
theme= theme.explode('5 esg 관련 테마 추출')
theme
# Out:
#         PublicationDate                                              title  \
# 0   2024-01-07T16:09:00          주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 0   2024-01-07T16:09:00          주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 0   2024-01-07T16:09:00          주식·채권·부동산의 대안으로 떠오른 우라늄 투자 [최준영의 경제 바로읽기]
# 1   2024-01-20T00:13:00                  [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 1   2024-01-20T00:13:00                  [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 1   2024-01-20T00:13:00                  [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 1   2024-01-20T00:13:00                  [선데이 칼럼] 2024년 글로벌 키워드, GPS에서 찾아야
# 2   2024-01-10T17:55:00          ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 2   2024-01-10T17:55:00          ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 2   2024-01-10T17:55:00          ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# 3   2024-01-10T17:55:00          ‘무죄’ 김태오 DGB금융그룹 회장…'글로벌 100년 기업' 빅 스텝 밟나
# ...

# %%
comment.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료_comment.csv', index=False)
corp.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료_corp.csv', index=False)
esg_threaten.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료_esg_threaten.csv', index=False)
trend.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료_trend.csv', index=False)
stakeholder.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료_stakeholder.csv', index=False)
theme.to_csv('/Users/jinminseong/Desktop/3시연용데이터_article_summary_insights_완료_theme.csv', index=False)

# %% [markdown]
# # comment

# %%
stakeholder['PublicationDate'][1]
# Out:
# 1    2024-01-20T00:13:00
# 1    2024-01-20T00:13:00
# 1    2024-01-20T00:13:00
# 1    2024-01-20T00:13:00
# 1    2024-01-20T00:13:00
# Name: PublicationDate, dtype: object
